# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
final_df_hdb_pricing = pd.read_csv("C:/Users/hi/Desktop/DATA SCIENCE/FOR JOBS/Holmusk/final_df_hdb_pricing.csv")\
.drop("Unnamed: 0",axis=1)
final_df_hdb_pricing
# Out:
#         floor_area_sqm  lease_commence_date  resale_price  Month  Year  \
# 0                   31                 1977          9000      1  1990
# 1                   31                 1977          6000      1  1990
# 2                   31                 1977          8000      1  1990
# 3                   31                 1977          6000      1  1990
# 4                   73                 1976         47200      1  1990
# ...                ...                  ...           ...    ...   ...
# 851289             122                 1988        580000     12  2014
# 851290             146                 1988        540000     12  2014
# 851291             164                 1992        738000     12  2014
# 851292             152                 1985        592000     12  2014
# 851293             146                 1985        545000     12  2014
#
#         remaining_lease  town_0  town_1  town_2  town_3  ...  \
# ...

# %% [markdown]
# # Plotting our features against our label

# %%
hdb_pre_encoded = pd.read_csv("C:/Users/hi/Desktop/DATA SCIENCE/FOR JOBS/Holmusk/hdb_pre_encoded.csv")\
.drop("Unnamed: 0",axis=1)
hdb_pre_encoded
# Out:
#               town  flat_type block storey_range  floor_area_sqm  \
# 0       ANG MO KIO     1 ROOM   309     10 TO 12            31.0
# 1       ANG MO KIO     1 ROOM   309     04 TO 06            31.0
# 2       ANG MO KIO     1 ROOM   309     10 TO 12            31.0
# 3       ANG MO KIO     1 ROOM   309     07 TO 09            31.0
# 4       ANG MO KIO     3 ROOM   216     04 TO 06            73.0
# ...            ...        ...   ...          ...             ...
# 851289      YISHUN     5 ROOM   816     10 TO 12           122.0
# 851290      YISHUN  EXECUTIVE   325     10 TO 12           146.0
# 851291      YISHUN  EXECUTIVE   618     07 TO 09           164.0
# 851292      YISHUN  EXECUTIVE   277     07 TO 09           152.0
# 851293      YISHUN  EXECUTIVE   277     04 TO 06           146.0
#
#             flat_model  lease_commence_date  resale_price  Month  Year  \
# 0             IMPROVED                 1977        9000.0      1  1990
# ...

# %%
sns.pairplot(data=final_df_hdb_pricing,aspect= 3,
                  x_vars=['resale_price'],
                  y_vars=[i for i in final_df_hdb_pricing.drop("resale_price",axis=1).columns])

# %%
sns.pairplot(data=hdb_pre_encoded,aspect= 3,
                  x_vars=['resale_price'],
                  y_vars=[i for i in hdb_pre_encoded.drop("resale_price",axis=1).columns])
